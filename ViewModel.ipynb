# %%
from module.ResNet_CBAM import resnet18_cbam
from torchsummary import summary
from torchstat import stat
import torch


model = resnet18_cbam(pretrained=False)
# x = torch.randn(1, 1, 28, 28).requires_grad_(True)
#print(model)
print(summary(model,input_size = (3, 28, 28) , device="cpu"))

#print(stat(model, (3, 256, 256)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 14, 14]           9,408
#        BatchNorm2d-2           [-1, 64, 14, 14]             128
#               ReLU-3           [-1, 64, 14, 14]               0
#          MaxPool2d-4             [-1, 64, 7, 7]               0
#             Conv2d-5             [-1, 64, 7, 7]          36,864
#        BatchNorm2d-6             [-1, 64, 7, 7]             128
#               ReLU-7             [-1, 64, 7, 7]               0
#             Conv2d-8             [-1, 64, 7, 7]          36,864
#        BatchNorm2d-9             [-1, 64, 7, 7]             128
#              ReLU-10             [-1, 64, 7, 7]               0
#        BasicBlock-11             [-1, 64, 7, 7]               0
#            Conv2d-12             [-1, 64, 7, 7]          36,864
#       BatchNorm2d-13             [-1, 64, 7, 7]             128
# ...

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
from module.ResNet_CBAM import resnet18_cbam
from torchvision.models import resnet152,resnet101,resnext101_32x8d,alexnet,densenet201,efficientnet_b5,vgg16_bn,vgg19_bn,inception_v3,mobilenet_v3_large
import torch
from ptflops import get_model_complexity_info
from torchsummary import summary
from thop import profile

model = resnet18_cbam(pretrained=False)
#model = efficientnet_b5()
flops, params = get_model_complexity_info(model, (3, 256, 256), as_strings=True, print_per_layer_stat=True,output_precision=4)

print('Flops:  ' + flops)
print('Params: ' + params)
# Out:
# ResNet(
#   15.4864 M, 100.000% Params, 2.669 GMac, 100.000% MACs,
#   (conv1): Conv2d(9.408 k, 0.061% Params, 154.1407 MMac, 5.775% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(128, 0.001% Params, 2.0972 MMac, 0.079% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(0, 0.000% Params, 1.0486 MMac, 0.039% MACs, inplace=True)
#   (maxpool): MaxPool2d(0, 0.000% Params, 1.0486 MMac, 0.039% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     147.968 k, 0.955% Params, 607.1255 MMac, 22.747% MACs,
#     (0): BasicBlock(
#       73.984 k, 0.478% Params, 303.5628 MMac, 11.374% MACs,
#       (conv1): Conv2d(36.864 k, 0.238% Params, 150.9949 MMac, 5.657% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# 输出网络结构
from torchviz import make_dot

x = torch.randn(1, 1, 28, 28).requires_grad_(True)
y = model(x)

myDilaCNN_vis = make_dot(y, params=dict(list(model.named_parameters()) + [('x', x)]))
myDilaCNN_vis
